# %%
# Import packages
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# Daten laden
df = pd.read_csv("data/CE-BVerfG_Metadaten.csv")

df.head()
# Out:
#                                               doc_id gericht       datum  \
# 0  BVerfG_1951-09-09_S_2_BvQ_0001_51_NA_NA_NA_NA.txt  BVerfG  1951-09-09
# 1  BVerfG_1952-09-10_S_1_BvR_0379_52_NA_Fristlauf...  BVerfG  1952-09-10
# 2  BVerfG_1952-10-10_S_1_BvR_0511_52_NA_BGH-Straf...  BVerfG  1952-10-10
# 3  BVerfG_1957-01-16_S_1_BvR_0253_56_NA_NA_NA_NA.txt  BVerfG  1957-01-16
# 4  BVerfG_1958-01-15_S_1_BvR_0400_51_NA_Lüth_7_19...  BVerfG  1958-01-15
#
#   entscheidung_typ spruchkoerper_typ  spruchkoerper_az registerzeichen  \
# 0                B                 S               2.0             BvQ
# 1                B                 S               1.0             BvR
# 2                B                 S               1.0             BvR
# 3                U                 S               1.0             BvR
# 4                B                 S               1.0             BvR
#
#                                        verfahrensart  eingangsnummer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8213 entries, 0 to 8212
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   doc_id             8213 non-null   object
#  1   gericht            8213 non-null   object
#  2   datum              8213 non-null   object
#  3   entscheidung_typ   8213 non-null   object
#  4   spruchkoerper_typ  8213 non-null   object
#  5   spruchkoerper_az   8206 non-null   float64
#  6   registerzeichen    8213 non-null   object
#  7   verfahrensart      8213 non-null   object
#  8   eingangsnummer     8213 non-null   int64
#  9   eingangsjahr_az    8213 non-null   int64
#  10  eingangsjahr_iso   8213 non-null   int64
#  11  entscheidungsjahr  8213 non-null   int64
#  12  kollision          42 non-null     object
#  13  name               731 non-null    object
#  14  band               731 non-null    float64
#  15  seite              731 non-null    float64
# ...

# %%
print(df.columns)
df.nunique()
# Out:
# Index(['doc_id', 'gericht', 'datum', 'entscheidung_typ', 'spruchkoerper_typ',
#        'spruchkoerper_az', 'registerzeichen', 'verfahrensart',
#        'eingangsnummer', 'eingangsjahr_az', 'eingangsjahr_iso',
#        'entscheidungsjahr', 'kollision', 'name', 'band', 'seite',
#        'aktenzeichen', 'aktenzeichen_alle', 'ecli', 'zitiervorschlag',
#        'kurzbeschreibung', 'pressemitteilung', 'praesi', 'v_praesi', 'richter',
#        'zeichen', 'tokens', 'typen', 'saetze', 'version', 'doi_concept',
#        'doi_version', 'lizenz'],
#       dtype='object')
# doc_id               8213
# gericht                 1
# datum                3876
# entscheidung_typ        2
# spruchkoerper_typ       4
# spruchkoerper_az        2
# registerzeichen        15
# verfahrensart          15
# eingangsnummer       2716
# eingangsjahr_az        46
# eingangsjahr_iso       46
# entscheidungsjahr      39
# kollision               4
# name                  718
# band                   67
# ...

# %%
df.loc[:, df.nunique() == 1]
# Out:
#      gericht     version             doi_concept             doi_version  \
# 0     BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 1     BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 2     BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 3     BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 4     BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# ...      ...         ...                     ...                     ...
# 8208  BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 8209  BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 8210  BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 8211  BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
# 8212  BVerfG  2022-02-01  10.5281/zenodo.3902658  10.5281/zenodo.5910152
#
#                                    lizenz
# 0     Creative Commons Zero 1.0 Universal
# ...

# %%
df_col_drop = df.loc[:, df.nunique() > 1]
df_col_drop.columns
# Out:
# Index(['doc_id', 'datum', 'entscheidung_typ', 'spruchkoerper_typ',
#        'spruchkoerper_az', 'registerzeichen', 'verfahrensart',
#        'eingangsnummer', 'eingangsjahr_az', 'eingangsjahr_iso',
#        'entscheidungsjahr', 'kollision', 'name', 'band', 'seite',
#        'aktenzeichen', 'aktenzeichen_alle', 'ecli', 'zitiervorschlag',
#        'kurzbeschreibung', 'pressemitteilung', 'praesi', 'v_praesi', 'richter',
#        'zeichen', 'tokens', 'typen', 'saetze'],
#       dtype='object')

# %%
df_col_drop.nunique()
# Out:
# doc_id               8213
# datum                3876
# entscheidung_typ        2
# spruchkoerper_typ       4
# spruchkoerper_az        2
# registerzeichen        15
# verfahrensart          15
# eingangsnummer       2716
# eingangsjahr_az        46
# eingangsjahr_iso       46
# entscheidungsjahr      39
# kollision               4
# name                  718
# band                   67
# seite                 323
# aktenzeichen         7593
# aktenzeichen_alle    7704
# ecli                 8213
# zitiervorschlag      8213
# kurzbeschreibung     6893
# pressemitteilung     1793
# praesi                 10
# v_praesi               12
# richter               483
# zeichen              7122
# tokens               4346
# typen                1995
# saetze                832
# dtype: int64

# %%
df_col_drop.isna().sum()
# Out:
# doc_id                  0
# datum                   0
# entscheidung_typ        0
# spruchkoerper_typ       0
# spruchkoerper_az        7
# registerzeichen         0
# verfahrensart           0
# eingangsnummer          0
# eingangsjahr_az         0
# eingangsjahr_iso        0
# entscheidungsjahr       0
# kollision            8171
# name                 7482
# band                 7482
# seite                7482
# aktenzeichen            0
# aktenzeichen_alle       7
# ecli                    0
# zitiervorschlag         0
# kurzbeschreibung      397
# pressemitteilung     6310
# praesi                  0
# v_praesi                0
# richter                23
# zeichen                 0
# tokens                  0
# typen                   0
# saetze                  0
# dtype: int64
